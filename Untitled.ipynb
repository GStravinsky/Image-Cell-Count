# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import and preprate the data
D = h5py.File('breast.h5', 'r')
X,Y,P = D['images'],np.array(D['counts']),np.array(D['id'])

# %% [markdown]
# ## Question 1
# ### i)

# %%
# number of train examples
np.sum(P<14)
# Out:
# 5841

# %%
# number of test examples
np.sum(P>=14)
# Out:
# 1563

# %% [markdown]
# # ii)

# %%
for i in range(1,5): 
    plt.imshow(X[i])
    plt.show()

# %%
Y[1:5]
# Out:
# array([4, 9, 5, 6], dtype=int32)

# %%
plt.hist(Y)
# Out:
# (array([6.438e+03, 6.690e+02, 1.930e+02, 5.800e+01, 3.300e+01, 9.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 0.,  7., 14., 21., 28., 35., 42., 49., 56., 63., 70.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Y[Y<40])
# Out:
# (array([5544., 1078.,  382.,  171.,  100.,   53.,   30.,   22.,   11.,
#            6.]),
#  array([ 0. ,  3.9,  7.8, 11.7, 15.6, 19.5, 23.4, 27.3, 31.2, 35.1, 39. ]),
#  <a list of 10 Patch objects>)

# %%
np.sum(Y>40)
# Out:
# 5

# %%
plt.hist(Y, bins = [0,1,6,11,21,51,201])
# Out:
# (array([1.397e+03, 4.811e+03, 7.360e+02, 3.560e+02, 1.030e+02, 1.000e+00]),
#  array([  0,   1,   6,  11,  21,  51, 201]),
#  <a list of 6 Patch objects>)
